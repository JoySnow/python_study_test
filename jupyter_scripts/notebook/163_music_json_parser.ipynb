# %%
import json
s = None
with file('/tmp/155769351.out') as f:
    s = json.load(f)
# Out:
# {u'code': 200, u'result': {u'updateTime': 1474977094020, u'ordered': True, u'anonimous': False, u'creator': {u'followed': False, u'remarkName': None, u'expertTags': [u'\u6b27\u7f8e', u'\u5f71\u89c6\u539f\u58f0'], u'userId': 31925677, u'authority': 0, u'userType': 0, u'experts': {u'1': u'\u89c6\u9891\u8fbe\u4eba'}, u'gender': 1, u'backgroundImgId': 109951163039740567, u'city': 350200, u'mutual': False, u'avatarUrl': u'http://p1.music.126.net/ij7Ju0b3AjLPA5wWjjYd9g==/109951163092932590.jpg', u'avatarImgIdStr': u'109951163092932590', u'detailDescription': u'', u'province': 350000, u'description': u'', u'avatarImgId_str': u'109951163092932590', u'birthday': 654192000000, u'nickname': u'\u534a\u6cfd\u6811', u'vipType': 11, u'avatarImgId': 109951163092932590, u'defaultAvatar': False, u'djStatus': 10, u'accountStatus': 0, u'backgroundImgIdStr': u'109951163039740567', u'backgroundUrl': u'http://p1.music.126.net/obV7H1zUaj9kDPyK45kHjQ==/109951163039740567.jpg', u'signature': u'\u7f51\u6613\u8
# ...

# %%
s.keys()
# Out:
# [u'code', u'result']

# %%
s['result'].keys()
# Out:
# [u'updateTime',
#  u'ordered',
#  u'anonimous',
#  u'creator',
#  u'trackUpdateTime',
#  u'userId',
#  u'coverImgUrl',
#  u'commentCount',
#  u'artists',
#  u'newImported',
#  u'commentThreadId',
#  u'subscribed',
#  u'privacy',
#  u'id',
#  u'trackCount',
#  u'specialType',
#  u'status',
#  u'description',
#  u'subscribedCount',
#  u'tags',
#  u'coverImgId',
#  u'tracks',
#  u'highQuality',
#  u'subscribers',
#  u'playCount',
#  u'trackNumberUpdateTime',
#  u'createTime',
#  u'name',
#  u'cloudTrackCount',
#  u'shareCount',
#  u'adType',
#  u'totalDuration']

# %%
for k, v in s['result'].items():
    print ">>> ", k
    print v
# Out:
# >>>  updateTime
# 1474977094020
# >>>  ordered
# True
# >>>  anonimous
# False
# >>>  creator
# ...

# %%
songs = s['result']['tracks']

# %%
len(songs)
# Out:
# 57

# %%
song0 = songs[0]

# %%
song0.keys()
# Out:
# [u'bMusic',
#  u'hearTime',
#  u'mvid',
#  u'hMusic',
#  u'disc',
#  u'artists',
#  u'duration',
#  u'id',
#  u'album',
#  u'fee',
#  u'copyright',
#  u'no',
#  u'rtUrl',
#  u'ringtone',
#  u'rtUrls',
#  u'score',
#  u'rurl',
#  u'status',
#  u'ftype',
#  u'mp3Url',
#  u'audition',
#  u'playedNum',
#  u'commentThreadId',
#  u'mMusic',
#  u'lMusic',
#  u'copyrightId',
#  u'name',
#  u'rtype',
#  u'crbt',
#  u'popularity',
#  u'dayPlays',
#  u'alias',
#  u'copyFrom',
#  u'position',
#  u'starred',
#  u'starredNum']
