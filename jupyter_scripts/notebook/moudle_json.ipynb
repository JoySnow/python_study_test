# %%
#!/usr/bin/python
import json
#Function:Analyze json script
#Json is a script can descript data structure as xml, 
#for detail, please refer to "http://json.org/json-zh.html".

#Note:
#1.Also, if you write json script from python,
#you should use dump instead of load. pleaser refer to "help(json)".

# %%
#json file:
#The file content of temp.json is:
#{
# "name":"00_sample_case1",
# "description":"an example."
#}
f1 = file("/home/joy/Git/GraduationProject_PythonCrawler/webspider/webspider/spiders/config_shanghairanking_v1.json")
print type(f1)
s = json.load(f1)
print s
f1.close
# Out:
# <type 'file'>
# ...

# %%
print type(s)
print s["ARWUR"]["index_pub"]
# Out:
# <type 'dict'>
# //*[@id="UniversityRanking "]/tbody/tr/td[10]/div/text()

# %%
for ranking_name in s:
    print ranking_name
    for rules in s[ranking_name]:
        print rules
        #start_url = rules["start_url"]
        #print rules[start_url]
# Out:
# ARWUR
# 11
# 10
# 6
# 1
# 3
# 2
# 5
# 4
# 7
# start_url
# 9
# 8
# FieldMED
# 6
# 1
# 3
# 2
# 5
# 4
# 7
# start_url
# 9
# 8

# %%
for ranking_name in s:
    print ranking_name
    print s[ranking_name]["start_url"]
    for rules in s[ranking_name]:
        print rules
        #start_url = rules["start_url"]
        #print rules[start_url]
# Out:
# ARWUR
# http://www.shanghairanking.cn/ARWU2015.html
# 11
# 10
# 6
# 1
# 3
# 2
# 5
# 4
# 7
# start_url
# 9
# 8
# FieldMED
# http://www.shanghairanking.cn/FieldMED2015.html
# 6
# 1
# 3
# 2
# 5
# 4
# 7
# start_url
# 9
# 8

# %%
import json
#json file:
#The file content of temp.json is:
#{
# "name":"00_sample_case1",
# "description":"an example."
#}
f1 = file("/tmp/rabbitmq_cluster_new_users-mapper_output")
print type(f1)
s = json.load(f1)
print s
f1.close
# Out:
# <type 'file'>
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-7-4ac0e34401b0> in <module>()
#       8 f1 = file("/tmp/rabbitmq_cluster_new_users-mapper_output")
#       9 print type(f1)
# ---> 10 s = json.load(f1)
#      11 print s
#      12 f1.close
#
# /usr/lib64/python2.7/json/__init__.pyc in load(fp, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     289         parse_float=parse_float, parse_int=parse_int,
#     290         parse_constant=parse_constant, object_pairs_hook=object_pairs_hook,
# --> 291         **kw)
#     292
#     293
#
# /usr/lib64/python2.7/json/__init__.pyc in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     337             parse_int is None and parse_float is None and
# ...

# %%
import json
f1 = file("/tmp/rhev/insights-coordinator-rhevuN5fu0/metadata-beauty.json") #rhevm40-72
f2 = file("/tmp/rhev/insights-coordinator-rhevIhGdib/metadata.json") #rhevm36-68
f3 = file("/tmp/rhev/insights-coordinator-rhevZ8KuyR/metadata.json") #rhevm35?
print type(f1)
s1 = json.load(f1)
s2 = json.load(f2)
s3 = json.load(f3)
print type(s1)
f1.close
f2.close
f3.close

for hy in s1["hosts"]:
    print hy["name"], hy["type"]
    print hy["os"]["version"]["full_version"], hy["version"]["full_version"]
    
print "-------------------"

for hy in s2["hosts"]:
    print hy["name"], hy["type"]
    print hy["os"]["version"]["full_version"], hy["version"]["full_version"]

print "-------------------"
    
for hy in s3["hosts"]:
    print hy["name"], hy["type"]
    print hy["os"]["version"]["full_version"], hy["version"]["full_version"]
# Out:
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-1-a3f0eddd8532> in <module>()
#       1 import json
# ----> 2 f1 = file("/tmp/rhev/insights-coordinator-rhevuN5fu0/metadata-beauty.json") #rhevm40-72
#       3 f2 = file("/tmp/rhev/insights-coordinator-rhevIhGdib/metadata.json") #rhevm36-68
#       4 f3 = file("/tmp/rhev/insights-coordinator-rhevZ8KuyR/metadata.json") #rhevm35?
#       5 print type(f1)
#
# IOError: [Errno 2] No such file or directory: '/tmp/rhev/insights-coordinator-rhevuN5fu0/metadata-beauty.json'

# %%
import json
#f1 = file("/tmp/rhev/insights-coordinator-rhevuN5fu0/metadata-beauty.json") #rhevm40-72
#f2 = file("/tmp/rhev/insights-coordinator-rhevIhGdib/metadata.json") #rhevm36-68
f1 = file("/home/joy/Documents/rhev-test-data/rhev35-6/insights-coordinator-rhevZ8KuyR/metadata.json") #rhevm35?
print type(f1)
s1 = json.load(f1)

print type(s1)
f1.close

print "-------------------"

for vm in s1["vms"]:
    print vm["name"], vm["type"]
    nics = vm["nics"]
    for nic in nics:
        print nic["mac"]["address"]
    #print vm["status"]["state"]
    #["full_version"], hy["version"]["full_version"]
# Out:
# <type 'file'>
# <type 'dict'>
# -------------------
# RHEL6764 server
# 00:01:a4:ae:4c:00
# RHEL6764_test_disk server
# 00:01:a4:ae:4c:01
# Test_Pool-1 server
# 00:01:a4:ae:4c:03
# Test_Pool-2 server
# 00:01:a4:ae:4c:04
# vm_base_on_template server
# 00:01:a4:ae:4c:02

# %%
import json
meta = json.load(file("/home/joy/Work/insights-core/insights/parsers/tests/rhev_metadata.json"))
print meta
# Out:
# {u'storagedomains': [{u'comment': None, u'templates': [], u'warning_low_space_indicator': u'10', u'wipe_after_delete': u'False', u'disksnapshots': [{u'comment': None, u'logical_name': None, u'storage_domains': {u'active': None, u'total': None, u'storage_domain': [{u'comment': None, u'available': None, u'warning_low_space_indicator': None, u'wipe_after_delete': None, u'committed': None, u'actions': None, u'href': None, u'data_center': None, u'id': u'dc590add-4468-434d-9ea8-4739ae72f5b4', u'external_status': None, u'data_centers': None, u'storage': None, u'master': None, u'import': None, u'type': None, u'storage_format': None, u'status': None, u'used': None, u'description': None, u'format': None, u'host': None, u'link': [], u'destroy': None, u'name': None, u'critical_space_action_blocker': None, u'creation_status': None}], u'actions': None, u'size': None}, u'wipe_after_delete': u'False', u'propagate_errors': u'False', u'actions': None, u'active': None, u'sgio': None, u'href': u'/ovirt-
# ...
